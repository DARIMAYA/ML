# %% [markdown]
# # Лабораторная работа 6 #

# %% [markdown]
# ## Выполнила: Иванова Дарья Сергеевна БПМ-23-ПО-2

# %% [markdown]
# Задача: Необходимо реализовать классификатор изображений зерен на основе предобученной нейронной сети ResNet50. В работе используется transfer learning: сверточная часть модели замораживается, а дообучается только новая классифицирующая голова под два класса зерен. Для обучения используется датасет с папками train и test, где соответствие папок и классов задаётся через format.json. После обучения модель проверяется на тестовой выборке. Результаты классификации сохраняются в CSV-файл с путём к изображению, истинным классом и предсказанным классом.

# %%
# %pip install -q numpy pandas matplotlib seaborn pillow scikit-learn torch torchvision
