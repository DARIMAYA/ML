# %% [markdown]
# # Лабораторная работа 4 #

# %% [markdown]
# ## Выполнила: Иванова Дарья Сергеевна БПМ-23-ПО-2

# %% [markdown]
# Задача: Необходимо сгруппировать комментаторов по стилю общения на основе признаков их комментариев: длины текста, эмоциональной пунктуации, доли заглавных букв, лексического разнообразия и частоты отдельных речевых маркеров. Дополнительно в работе учитываются токсичная, конспирологическая, политически окрашенная и вежливая лексика. На основе этих признаков выполняется кластеризация пользователей методом K-Means и визуализация групп с помощью PCA. Также рассчитывается показатель troll_score, позволяющий выделить комментаторов с признаками троллинга и конфликтного поведения. Для поиска пользователей, близких к автору статьи по языку, используется TF-IDF-векторизация и косинусная близость между текстами статей и комментариями.

# %%
# %pip install -q pandas numpy scikit-learn matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# %%
articles = pd.read_csv('articles_clean.csv', encoding='utf-8-sig')
comments = pd.read_csv('comments_clean.csv', encoding='utf-8-sig')

articles.columns = articles.columns.str.strip().str.lower()
comments.columns = comments.columns.str.strip().str.lower()

print("Статьи:", articles.shape)
print("Комментарии:", comments.shape)
display(articles.head())
display(comments.head())
